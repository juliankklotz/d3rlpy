# %%
import os
from d3rlpy.logging import UnifiedFileAdapterFactory

os.environ["D3RLPY_DATASETS_PATH"] = "/gpfs/data/fs72297/jklotz/programming_data/d3rlpy_data"
os.makedirs(os.environ["D3RLPY_DATASETS_PATH"], exist_ok=True)
os.environ["MINARI_DATASETS_PATH"] = "/gpfs/data/fs72297/jklotz/programming_data/d3rlpy_data/minari_data"
os.makedirs(os.environ["MINARI_DATASETS_PATH"], exist_ok=True)

import d3rlpy

dataset, env = d3rlpy.datasets.get_cartpole()

seed = 1

dataset_name = "cartpole"
# fix seed
d3rlpy.seed(seed)
d3rlpy.envs.seed_env(env, seed)

if "cartpole" in dataset_name:
    target_return = 200
else:
    raise ValueError("unsupported dataset")

discrete_tacr = d3rlpy.algos.DiscreteTACRConfig(
    batch_size=64,
    actor_learning_rate=1e-4,
    actor_optim_factory=d3rlpy.optimizers.AdamWFactory(
        weight_decay=1e-4,
        clip_grad_norm=0.25,
        lr_scheduler_factory=d3rlpy.optimizers.WarmupSchedulerFactory(
            warmup_steps=10000#10000
        ),
    ),
    actor_encoder_factory=d3rlpy.models.VectorEncoderFactory(
        [128],
        exclude_last_activation=True,
    ),
    observation_scaler=d3rlpy.preprocessing.StandardObservationScaler(),
    position_encoding_type=d3rlpy.PositionEncodingType.SIMPLE,
    context_size=20,
    num_heads=1,
    num_layers=3,
    max_timestep=1000,
    compile_graph=True,
).create(device="cuda:0")

discrete_tacr.fit(
    dataset,
    n_steps=100000,# 100000,
    n_steps_per_epoch=1000,# 1000,
    save_interval=100,
    eval_env=env,
    eval_target_return=target_return,
    experiment_name=f"Discrete_TACR_{dataset_name}_{seed}",
    logger_adapter=UnifiedFileAdapterFactory(),
    n_trials=50,
    eval_gaps=1
)
# Out:
# 2025-07-26 18:05.18 [info     ] Signatures have been automatically determined. action_signature=Signature(dtype=[dtype('int32')], shape=[(1,)]) observation_signature=Signature(dtype=[dtype('float32')], shape=[(4,)]) reward_signature=Signature(dtype=[dtype('float32')], shape=[(1,)])
# 2025-07-26 18:05.18 [info     ] Action-space has been automatically determined. action_space=<ActionSpace.DISCRETE: 2>
# 2025-07-26 18:05.18 [info     ] Action size has been automatically determined. action_size=2
# 2025-07-26 18:05.18 [info     ] dataset info                   dataset_info=DatasetInfo(observation_signature=Signature(dtype=[dtype('float32')], shape=[(4,)]), action_signature=Signature(dtype=[dtype('int32')], shape=[(1,)]), reward_signature=Signature(dtype=[dtype('float32')], shape=[(1,)]), action_space=<ActionSpace.DISCRETE: 2>, action_size=2)
# 2025-07-26 18:05.18 [debug    ] Fitting observation scaler...  observation_scaler=standard
# 2025-07-26 18:05.19 [debug    ] Building models...
# 2025-07-26 18:05.19 [debug    ] Models have been built.
# 2025-07-26 18:05.19 [info     ] Directory is created at d3rlpy_logs/Discrete_TACR_cartpole_1_20250726180519
# 2025-07-26 18:05.19 [info     ] Parameters                     params={'observation_shape': [4], 'action_size': 2, 'config': {'type': 'discrete_tacr', 'params': {'batch_size': 64, 'gamma': 0.99, 'observation_scaler': {'type': 'standard', 'params': {'mean': [-0.031802961269558776, -0.0678269545177816, -0.010684792702375613, -0.012740997831035317], 'std': [0.6757181439025264, 0.8773039884465872, 0.11073491775259448, 0.5806876898556592], 'eps': 0.001}}, 'action_scaler': {'type': 'none', 'params': {}}, 'reward_scaler': {'type': 'none', 'params': {}}, 'compile_graph': True, 'context_size': 20, 'max_timestep': 1000, 'actor_learning_rate': 0.0001, 'critic_learning_rate': 0.0001, 'actor_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [128], 'activation': 'relu', 'use_batch_norm': False, 'use_layer_norm': False, 'dropout_rate': None, 'exclude_last_activation': True, 'last_activation': None}}, 'critic_encoder_factory': {'type': 'default', 'params': {'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None}}, 'actor_optim_factory': {'type': 'adam_w', 'params': {'clip_grad_norm': 0.25, 'lr_scheduler_factory': {'type': 'warmup', 'params': {'warmup_steps': 10000}}, 'betas': [0.9, 0.999], 'eps': 1e-08, 'weight_decay': 0.0001, 'amsgrad': False}}, 'critic_optim_factory': {'type': 'adam', 'params': {'clip_grad_norm': None, 'lr_scheduler_factory': {'type': 'none', 'params': {}}, 'betas': [0.9, 0.999], 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'num_heads': 1, 'num_layers': 3, 'attn_dropout': 0.1, 'resid_dropout': 0.1, 'embed_dropout': 0.1, 'activation_type': 'relu', 'embed_activation_type': 'tanh', 'position_encoding_type': <PositionEncodingType.SIMPLE: 'simple'>, 'n_critics': 2, 'alpha': 2.5, 'tau': 0.005}}}
# Epoch 1/100: 100%|██████████| 1000/1000 [00:05<00:00, 183.41it/s, actor_loss=-1.59, critic_loss=0.0267]
# 2025-07-26 18:05.24 [info     ] New best score                 epoch=1 score=99.0
# 2025-07-26 18:05.24 [info     ] Saving model 'd3rlpy_logs/Discrete_TACR_cartpole_1_20250726180519/model_epoch_1.d3' epoch=1
# 2025-07-26 18:05.24 [info     ] Model parameters are saved to d3rlpy_logs/Discrete_TACR_cartpole_1_20250726180519/model_epoch_1.d3
# 2025-07-26 18:05.24 [info     ] Discrete_TACR_cartpole_1_20250726180519: epoch=1 step=1000 epoch=1 metrics={'time_sample_batch': 0.001926654815673828, 'time_algorithm_update': 0.003418557167053223, 'actor_loss': -1.591026759684086, 'critic_loss': 0.026425726443121675, 'time_step': 0.005422146797180176, 'eval_episode_mean_reward': 99.0, 'eval_episode_median_reward': 99.0, 'eval_episode_std_reward': 0.0, 'eval_episode_min_reward': 99.0, 'eval_episode_max_reward': 99.0, 'eval_episode_count': 1.0} step=1000
# Epoch 2/100: 100%|██████████| 1000/1000 [00:04<00:00, 215.15it/s, actor_loss=-1.6, critic_loss=0.00156]
# 2025-07-26 18:05.36 [info     ] Discrete_TACR_cartpole_1_20250726180519: epoch=2 step=2000 epoch=2 metrics={'time_sample_batch': 0.001912693977355957, 'time_algorithm_update': 0.002631978988647461, 'actor_loss': -1.6002516552209853, 'critic_loss': 0.0015687839658348822, 'time_step': 0.004620016574859619, 'eval_episode_mean_reward': 65.0, 'eval_episode_median_reward': 30.5, 'eval_episode_std_reward': 73.29392880723478, 'eval_episode_min_reward': 13.0, 'eval_episode_max_reward': 383.0, 'eval_episode_count': 50.0} step=2000
# Epoch 3/100: 100%|██████████| 1000/1000 [00:04<00:00, 212.20it/s, actor_loss=-1.61, critic_loss=0.00316]
# 2025-07-26 18:05.51 [info     ] Discrete_TACR_cartpole_1_20250726180519: epoch=3 step=3000 epoch=3 metrics={'time_sample_batch': 0.0019094250202178955, 'time_algorithm_update': 0.002696834564208984, 'actor_loss': -1.6125800038576126, 'critic_loss': 0.0031776770398719238, 'time_step': 0.0046830039024353025, 'eval_episode_mean_reward': 88.4, 'eval_episode_median_reward': 92.0, 'eval_episode_std_reward': 60.14515774357899, 'eval_episode_min_reward': 15.0, 'eval_episode_max_reward': 229.0, 'eval_episode_count': 50.0} step=3000
# Epoch 4/100: 100%|██████████| 1000/1000 [00:04<00:00, 212.21it/s, actor_loss=-1.63, critic_loss=0.00657]
# 2025-07-26 18:06.02 [info     ] Discrete_TACR_cartpole_1_20250726180519: epoch=4 step=4000 epoch=4 metrics={'time_sample_batch': 0.0019082818031311035, 'time_algorithm_update': 0.002698965787887573, 'actor_loss': -1.625323306798935, 'critic_loss': 0.006597469783155247, 'time_step': 0.004684011220932007, 'eval_episode_mean_reward': 58.54, 'eval_episode_median_reward': 31.5, 'eval_episode_std_reward': 51.86876131160258, 'eval_episode_min_reward': 10.0, 'eval_episode_max_reward': 204.0, 'eval_episode_count': 50.0} step=4000
# Epoch 5/100: 100%|██████████| 1000/1000 [00:04<00:00, 212.37it/s, actor_loss=-1.63, critic_loss=0.0142]
# 2025-07-26 18:06.17 [info     ] Discrete_TACR_cartpole_1_20250726180519: epoch=5 step=5000 epoch=5 metrics={'time_sample_batch': 0.0019156715869903564, 'time_algorithm_update': 0.0026930081844329834, 'actor_loss': -1.6316079457998276, 'critic_loss': 0.014294731792528182, 'time_step': 0.004681712150573731, 'eval_episode_mean_reward': 89.82, 'eval_episode_median_reward': 88.5, 'eval_episode_std_reward': 57.74727352871302, 'eval_episode_min_reward': 11.0, 'eval_episode_max_reward': 209.0, 'eval_episode_count': 50.0} step=5000
# Epoch 6/100: 100%|██████████| 1000/1000 [00:04<00:00, 212.34it/s, actor_loss=-1.64, critic_loss=0.0326]
# 2025-07-26 18:06.31 [info     ] Discrete_TACR_cartpole_1_20250726180519: epoch=6 step=6000 epoch=6 metrics={'time_sample_batch': 0.0019068617820739745, 'time_algorithm_update': 0.002698505163192749, 'actor_loss': -1.639028012752533, 'critic_loss': 0.03274694845918566, 'time_step': 0.00468143892288208, 'eval_episode_mean_reward': 80.08, 'eval_episode_median_reward': 67.0, 'eval_episode_std_reward': 58.060602821534665, 'eval_episode_min_reward': 11.0, 'eval_episode_max_reward': 203.0, 'eval_episode_count': 50.0} step=6000
# Epoch 7/100: 100%|██████████| 1000/1000 [00:04<00:00, 212.52it/s, actor_loss=-1.64, critic_loss=0.0879]
# 2025-07-26 18:06.43 [info     ] Discrete_TACR_cartpole_1_20250726180519: epoch=7 step=7000 epoch=7 metrics={'time_sample_batch': 0.0019057328701019287, 'time_algorithm_update': 0.002693734407424927, 'actor_loss': -1.6449699975252152, 'critic_loss': 0.08851580352708698, 'time_step': 0.004676353693008423, 'eval_episode_mean_reward': 69.5, 'eval_episode_median_reward': 56.0, 'eval_episode_std_reward': 48.102078957151114, 'eval_episode_min_reward': 13.0, 'eval_episode_max_reward': 203.0, 'eval_episode_count': 50.0} step=7000
# Epoch 8/100: 100%|██████████| 1000/1000 [00:04<00:00, 211.82it/s, actor_loss=-1.65, critic_loss=0.272]
# 2025-07-26 18:06.56 [info     ] Discrete_TACR_cartpole_1_20250726180519: epoch=8 step=8000 epoch=8 metrics={'time_sample_batch': 0.001915938138961792, 'time_algorithm_update': 0.0027008864879608154, 'actor_loss': -1.6454479805231095, 'critic_loss': 0.27352444390952585, 'time_step': 0.004692798852920533, 'eval_episode_mean_reward': 74.04, 'eval_episode_median_reward': 58.5, 'eval_episode_std_reward': 56.631779064408704, 'eval_episode_min_reward': 12.0, 'eval_episode_max_reward': 208.0, 'eval_episode_count': 50.0} step=8000
# Epoch 9/100:  14%|█▍        | 141/1000 [00:00<00:04, 206.86it/s, actor_loss=-1.65, critic_loss=0.517]
